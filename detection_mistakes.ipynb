# %% [markdown]
# # Finding Detection Mistakes with FiftyOne
#
# Annotations mistakes create an artificial ceiling on the performance of your models. However, finding these mistakes by hand is at least as arduous as the original annotation work! Enter FiftyOne.
#
# In [this tutorial](https://voxel51.com/docs/fiftyone/tutorials/detection_mistakes.html), we explore how FiftyOne can be used to help you find mistakes in your object detection annotations. To detect mistakes in classification datasets, check out [this tutorial](https://voxel51.com/docs/fiftyone/tutorials/classification_mistakes.html).
#
# We'll cover the following concepts:
#
# - Loading your existing dataset [into FiftyOne](https://voxel51.com/docs/fiftyone/user_guide/dataset_creation/index.html)
# - [Adding model predictions](https://voxel51.com/docs/fiftyone/recipes/adding_detections.html) to your dataset
# - Computing insights into your dataset relating to [possible label mistakes](https://voxel51.com/docs/fiftyone/user_guide/brain.html#label-mistakes)
# - Visualizing mistakes in the [FiftyOne App](https://voxel51.com/docs/fiftyone/user_guide/app.html)
#
# **So, what's the takeaway?**
#
# FiftyOne can help you find and correct label mistakes in your datasets, enabling you to curate higher quality datasets and, ultimately, train better models!

# %% [markdown]
# ## Setup

# %% [markdown]
# In order to compute mistakenness, your dataset needs to have two [detections fields](https://voxel51.com/docs/fiftyone/user_guide/using_datasets.html#object-detection), one with your ground truth annotations and one with your model predictions.

# %%
import json

import fiftyone as fo
import fiftyone.brain as fob
from fiftyone import ViewField as F

# %%
# A name for the dataset
name = "my-dataset"

# The directory containing the source images
data_path = "/media/data/datasets/TIL2021_CV_dataset/images/c3_test/images"

# The path to the COCO labels JSON file
labels_path = "/media/data/datasets/TIL2021_CV_dataset/images/c3_test/c3_test.json"

# The path to the COCO predictions JSON file
preds_path = "/media/data/datasets/TIL2021_CV_dataset/images/c3_test/til21_c3_pred.json"

# %%
with open(labels_path) as json_file:
    labels_data = json.load(json_file)
    
with open(preds_path) as json_file:
    preds_data = json.load(json_file)

# %%
# run this if getting Dataset already exists error in the next step
# fo.load_dataset(name).delete()

# %%
# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_type=fo.types.COCODetectionDataset,
    data_path=data_path,
    labels_path=labels_path,
    name=name,
)
# Out:
#  100% |█████████████████| 400/400 [955.2ms elapsed, 0s remaining, 418.7 samples/s]

# %%
print(dataset)
# Out:
# Name:        my-dataset
# Media type:  image
# Num samples: 400
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.Metadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)

# %% [markdown]
# ## Add predictions to dataset

# %%
# Add predictions to samples
cat2name = {cat['id']:cat['name'] for cat in labels_data["categories"]}

with fo.ProgressBar() as pb:
    for sample in pb(dataset):
        filepath = sample.filepath
        filename = filepath.split('/')[-1]

        # get image_id of sample
        img_data = next(item for item in labels_data["images"] if item["file_name"] == filename)
        image_id = img_data["id"]
        img_w = img_data["width"]
        img_h = img_data["height"]

        # Convert detections to FiftyOne format
        detections = []
        for pred in (x for x in preds_data if x["image_id"] == image_id):
            # Convert to [top-left-x, top-left-y, width, height] in relative coordinates in [0, 1] x [0, 1]
            x, y, w, h = pred["bbox"]
            rel_box = [x / img_w, y / img_h, w / img_w, h / img_h]

            detections.append(
                fo.Detection(
                    label=cat2name[pred["category_id"]],
                    bounding_box=rel_box,
                    confidence=pred["score"]
                )
            )

        # Save predictions to dataset
        sample["predictions"] = fo.Detections(detections=detections)
        sample.save()
# Out:
#  100% |█████████████████| 400/400 [4.9s elapsed, 0s remaining, 77.6 samples/s]

# %%
# Print a sample ground truth detection
sample = dataset.first()
print(sample.predictions.detections[0])
# Out:
# <Detection: {
#     'id': '60e4137dd10584dfdd7dbd02',
#     'attributes': BaseDict({}),
#     'tags': BaseList([]),
#     'label': 'Chicken',
#     'bounding_box': BaseList([
#         0.391357421875,
#         0.2001953125,
#         0.59716796875,
#         0.7936197916666666,
#     ]),
#     'mask': None,
#     'confidence': 0.907,
#     'index': None,
# }>

# %% [markdown]
# Let's start by visualizing the dataset in the [FiftyOne App](https://voxel51.com/docs/fiftyone/user_guide/app.html):

# %%
# Launch the App in a dedicated browser tab
session = fo.launch_app(dataset, auto=False)
session.open_tab()
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.

# %% [markdown]
# When working with FiftyOne datasets that contain a field with `Detections`, you can create a [patches view](https://voxel51.com/docs/fiftyone/user_guide/app.html#viewing-object-patches) both through Python and directly in the FiftyOne App to view each detection as a separate sample.

# %%
patches_view = dataset.to_patches("ground_truth")
print(patches_view)
# Out:
# Dataset:     my-dataset
# Media type:  image
# Num patches: 572
# Tags:        []
# Patch fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.Metadata)
#     sample_id:    fiftyone.core.fields.ObjectIdField
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detection)
# View stages:
#     1. ToPatches(field='ground_truth')

# %%
# the app view updates automatically after running this
session.view = patches_view

# %% [markdown]
# Alternatively, open the App and click the [patches button](https://voxel51.com/docs/fiftyone/user_guide/app.html#viewing-object-patches), then select `ground_truth` to create the same view that we created above.

# %% [markdown]
# ## Compute mistakenness
#
# Now we're ready to assess the mistakenness of the ground truth detections.
#
# We can do so by running the [compute_uniqueness()](https://voxel51.com/docs/fiftyone/api/fiftyone.brain.html#fiftyone.brain.compute_mistakenness) method from the FiftyOne Brain:

# %%
# Compute mistakenness of annotations in `ground_truth` field using 
# predictions from `predictions` field as point of reference
fob.compute_mistakenness(dataset, "predictions", label_field="ground_truth")
# Out:
# Evaluating detections...
#  100% |█████████████████| 400/400 [10.0s elapsed, 0s remaining, 44.9 samples/s]
# Computing mistakenness...
#  100% |█████████████████| 400/400 [8.7s elapsed, 0s remaining, 48.9 samples/s]
# Mistakenness computation complete

# %% [markdown]
# The above method populates a number of fields on the samples of our dataset as well as the ground truth and predicted objects:
#
# New ground truth object attributes (in `ground_truth` field):
#
# - `mistakenness` (float): A measure of the likelihood that a ground truth object's label is incorrect
# - `mistakenness_loc`: A measure of the likelihood that a ground truth object's localization (bounding box) is inaccurate
# - `possible_spurious`: Ground truth objects that were not matched with a predicted object and are deemed to be likely spurious annotations will have this attribute set to True
#
# New predicted object attributes (in `predictions` field):
#
# - `possible_missing`: If a highly confident prediction with no matching ground truth object is encountered, this attribute is set to True to indicate that it is a likely missing ground truth annotation
#
# Sample-level fields:
#
# - `mistakenness`: The maximum mistakenness of the ground truth objects in each sample
# - `possible_spurious`: The number of possible spurious ground truth objects in each sample
# - `possible_missing`: The number of possible missing ground truth objects in each sample

# %%
# inspect the first sample in the dataset
print(dataset.first())
# Out:
# <Sample: {
#     'id': '60e4137cd10584dfdd7db6fa',
#     'media_type': 'image',
#     'filepath': '/media/data/datasets/TIL2021_CV_dataset/images/c3_test/images/1.jpg',
#     'tags': BaseList([]),
#     'metadata': <ImageMetadata: {
#         'size_bytes': None,
#         'mime_type': None,
#         'width': 1024,
#         'height': 768,
#         'num_channels': None,
#     }>,
#     'ground_truth': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f4',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.73994140625,
#                     0.38212239583333335,
#                     0.26005859375,
#                     0.48194010416666666,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.447,
#                 'mistakenness_loc': 0.5321332962383387,
#             }>,
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f5',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5505338541666667,
#                     0.15375,
#                     0.44714843750000005,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.09549999999999997,
#                 'mistakenness_loc': 0.12209398049207704,
#             }>,
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f6',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.2392578125,
#                     0.1859765625,
#                     0.40998697916666665,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.069,
#                 'mistakenness_loc': 0.20217151483861778,
#             }>,
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f7',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([0.51171875, 0.0, 0.48828125, 0.4506380208333333]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.15949999999999998,
#                 'mistakenness_loc': 0.2903560487057817,
#             }>,
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f8',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.1337109375,
#                     0.019752604166666667,
#                     0.37458984375,
#                     0.9790885416666667,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.04949999999999999,
#                 'mistakenness_loc': 0.3561411653467619,
#             }>,
#             <Detection: {
#                 'id': '60e4137cd10584dfdd7db6f9',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.3919921875,
#                     0.18580729166666665,
#                     0.58974609375,
#                     0.8141927083333332,
#                 ]),
#                 'mask': None,
#                 'confidence': None,
#                 'index': None,
#                 'supercategory': '',
#                 'iscrowd': 0,
#                 'mistakenness': 0.046499999999999986,
#                 'mistakenness_loc': 0.1137629194539177,
#             }>,
#         ]),
#     }>,
#     'predictions': <Detections: {
#         'detections': BaseList([
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd02',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.391357421875,
#                     0.2001953125,
#                     0.59716796875,
#                     0.7936197916666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.907,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd03',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.061640625,
#                     0.025716145833333332,
#                     0.445068359375,
#                     0.9742838541666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.901,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd04',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.001708984375,
#                     0.23046875,
#                     0.177734375,
#                     0.4127604166666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.862,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd05',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5437760416666667,
#                     0.15392578125,
#                     0.4541015625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.809,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd06',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.504150390625,
#                     0.0,
#                     0.47216796875,
#                     0.46794270833333335,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.681,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd07',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.838681640625,
#                     0.0011458333333333333,
#                     0.161318359375,
#                     0.5218098958333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.166,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd08',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.73791015625,
#                     0.08658854166666667,
#                     0.259521484375,
#                     0.7942708333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.106,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd09',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.24865234375,
#                     0.8765494791666667,
#                     0.122314453125,
#                     0.12190104166666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.104,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.819638671875,
#                     0.0,
#                     0.17224609375,
#                     0.8603515625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.022,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0028125,
#                     0.1865234375,
#                     0.179931640625,
#                     0.638671875,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.016,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.73046875,
#                     0.34065104166666665,
#                     0.26953125,
#                     0.5764973958333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.008,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.12146484375,
#                     0.0,
#                     0.404541015625,
#                     0.7945963541666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.007,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0025,
#                     0.2835286458333333,
#                     0.1561328125,
#                     0.7164713541666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.007,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd0f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5297916666666667,
#                     0.22357421875,
#                     0.47020833333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.007,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd10',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.35595703125,
#                     0.09016927083333333,
#                     0.4599609375,
#                     0.9098307291666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.006,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd11',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Bird',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.005,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd12',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dinosaur',
#                 'bounding_box': BaseList([
#                     0.504765625,
#                     0.0,
#                     0.474853515625,
#                     0.46403645833333335,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.004,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd13',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.58923828125,
#                     0.248046875,
#                     0.404541015625,
#                     0.71484375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.004,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd14',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.007080078125,
#                     0.5336979166666667,
#                     0.142822265625,
#                     0.3284505208333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.004,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd15',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.119384765625,
#                     0.08430989583333333,
#                     0.5107421875,
#                     0.9156901041666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd16',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Elephant',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd17',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.49548828125,
#                     0.0,
#                     0.492431640625,
#                     0.9095052083333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd18',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.259580078125,
#                     0.8768359375,
#                     0.172734375,
#                     0.11743489583333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd19',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Snake',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.26220703125,
#                     0.8725520833333333,
#                     0.2568359375,
#                     0.1259765625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Bird',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.23177083333333334,
#                     0.178408203125,
#                     0.408203125,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Elephant',
#                 'bounding_box': BaseList([
#                     0.5029296875,
#                     0.0,
#                     0.474609375,
#                     0.4690755208333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.003,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.186826171875,
#                     0.8752473958333334,
#                     0.1825,
#                     0.12190104166666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.204921875,
#                     0.2420703125,
#                     0.4964192708333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd1f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dog',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5413411458333334,
#                     0.15337890625,
#                     0.4586588541666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd20',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Elephant',
#                 'bounding_box': BaseList([
#                     0.388427734375,
#                     0.19075520833333334,
#                     0.60400390625,
#                     0.806640625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd21',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Snake',
#                 'bounding_box': BaseList([
#                     0.389404296875,
#                     0.1962890625,
#                     0.60302734375,
#                     0.8037109375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd22',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Snake',
#                 'bounding_box': BaseList([
#                     0.5029296875,
#                     0.0,
#                     0.474609375,
#                     0.4690755208333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd23',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([0.6748046875, 0.0, 0.322265625, 0.978515625]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd24',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Crocodile',
#                 'bounding_box': BaseList([
#                     0.5029296875,
#                     0.0,
#                     0.474609375,
#                     0.4690755208333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd25',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Cat',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5413411458333334,
#                     0.15337890625,
#                     0.4586588541666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd26',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Elephant',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5402083333333333,
#                     0.153623046875,
#                     0.45979166666666665,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd27',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Elephant',
#                 'bounding_box': BaseList([
#                     0.000244140625,
#                     0.22997395833333334,
#                     0.17626953125,
#                     0.4117838541666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd28',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dog',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd29',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dinosaur',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dog',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.22966145833333332,
#                     0.17822265625,
#                     0.4143880208333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Bird',
#                 'bounding_box': BaseList([
#                     0.49755859375,
#                     0.0,
#                     0.48828125,
#                     0.47346354166666665,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dinosaur',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5402083333333333,
#                     0.153623046875,
#                     0.45979166666666665,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Snake',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.23177083333333334,
#                     0.178408203125,
#                     0.408203125,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.469970703125,
#                     0.4303385416666667,
#                     0.51416015625,
#                     0.5638020833333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd2f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Cat',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.002,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd30',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Bird',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5402083333333333,
#                     0.153623046875,
#                     0.45979166666666665,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd31',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dinosaur',
#                 'bounding_box': BaseList([
#                     0.000244140625,
#                     0.22997395833333334,
#                     0.17626953125,
#                     0.4117838541666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd32',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dinosaur',
#                 'bounding_box': BaseList([
#                     0.388427734375,
#                     0.19075520833333334,
#                     0.60400390625,
#                     0.806640625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd33',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Crocodile',
#                 'bounding_box': BaseList([
#                     0.389404296875,
#                     0.1962890625,
#                     0.60302734375,
#                     0.8037109375,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd34',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Snake',
#                 'bounding_box': BaseList([
#                     0.0,
#                     0.5424739583333333,
#                     0.15228515625,
#                     0.4514973958333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd35',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Crocodile',
#                 'bounding_box': BaseList([
#                     0.000244140625,
#                     0.22997395833333334,
#                     0.17626953125,
#                     0.4117838541666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd36',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.063232421875,
#                     0.4254557291666667,
#                     0.4033203125,
#                     0.5631510416666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd37',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Crocodile',
#                 'bounding_box': BaseList([
#                     0.0625,
#                     0.026041666666666668,
#                     0.44140625,
#                     0.9739583333333334,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd38',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.023193359375,
#                     0.1484375,
#                     0.3916015625,
#                     0.8515625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd39',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Cat',
#                 'bounding_box': BaseList([
#                     0.001708984375,
#                     0.23046875,
#                     0.177734375,
#                     0.4127604166666667,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3a',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.019287109375,
#                     0.5387369791666666,
#                     0.336669921875,
#                     0.4446614583333333,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3b',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Cat',
#                 'bounding_box': BaseList([
#                     0.38916015625,
#                     0.193359375,
#                     0.580078125,
#                     0.8033854166666666,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3c',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dog',
#                 'bounding_box': BaseList([
#                     0.504765625,
#                     0.0,
#                     0.474853515625,
#                     0.46403645833333335,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3d',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.00060546875,
#                     0.41911458333333335,
#                     0.156982421875,
#                     0.4716796875,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3e',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Chicken',
#                 'bounding_box': BaseList([
#                     0.3046875,
#                     0.005364583333333333,
#                     0.6689453125,
#                     0.4150390625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd3f',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Dog',
#                 'bounding_box': BaseList([
#                     0.388427734375,
#                     0.19075520833333334,
#                     0.60400390625,
#                     0.806640625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd40',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Bird',
#                 'bounding_box': BaseList([
#                     0.388427734375,
#                     0.19075520833333334,
#                     0.60400390625,
#                     0.806640625,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#             <Detection: {
#                 'id': '60e4137dd10584dfdd7dbd41',
#                 'attributes': BaseDict({}),
#                 'tags': BaseList([]),
#                 'label': 'Cat',
#                 'bounding_box': BaseList([
#                     0.504765625,
#                     0.0,
#                     0.474853515625,
#                     0.46403645833333335,
#                 ]),
#                 'mask': None,
#                 'confidence': 0.001,
#                 'index': None,
#             }>,
#         ]),
#     }>,
#     'mistakenness': 0.447,
#     'possible_missing': 0,
#     'possible_spurious': 0,
# }>

# %% [markdown]
# ## Analyzing the results
#
# Let's use FiftyOne to investigate the results.
#
# First, let's show the samples with the most likely annotation mistakes:

# %%
# Sort by likelihood of mistake (most likely first)
mistake_view = dataset.sort_by("mistakenness", reverse=True)

# Print some information about the view
print(mistake_view)
# Out:
# Dataset:     my-dataset
# Media type:  image
# Num samples: 400
# Tags:        []
# Sample fields:
#     id:                fiftyone.core.fields.ObjectIdField
#     filepath:          fiftyone.core.fields.StringField
#     tags:              fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.Metadata)
#     ground_truth:      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     predictions:       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Detections)
#     mistakenness:      fiftyone.core.fields.FloatField
#     possible_missing:  fiftyone.core.fields.IntField
#     possible_spurious: fiftyone.core.fields.IntField
# View stages:
#     1. SortBy(field_or_expr='mistakenness', reverse=True)

# %%
# Inspect some samples and detections
# This is the first detection of the first sample
print(mistake_view.first().ground_truth.detections[0])
# Out:
# <Detection: {
#     'id': '60e4137cd10584dfdd7db82e',
#     'attributes': BaseDict({}),
#     'tags': BaseList([]),
#     'label': 'Elephant',
#     'bounding_box': BaseList([
#         0.2568359375,
#         0.3177083333333333,
#         0.412109375,
#         0.4739583333333333,
#     ]),
#     'mask': None,
#     'confidence': None,
#     'index': None,
#     'supercategory': '',
#     'iscrowd': 0,
#     'mistakenness': 0.9535,
#     'mistakenness_loc': 0.25206893883866816,
# }>

# %% [markdown]
# Let's use the App to visually inspect the results:

# %%
# Show the samples we processed in rank order by the mistakenness
session.view = mistake_view

# %% [markdown]
# Another useful query is to find all objects that have a high mistakenness, lets say > 0.9:

# %%
session.view = dataset.filter_labels("ground_truth", F("mistakenness") > 0.9)

# %% [markdown]
# Looking through the results, we see some annotations that may be incorrect.
#
# We can use a similar workflow to look at objects that may be localized poorly:

# %%
session.view = dataset.filter_labels("ground_truth", F("mistakenness_loc") > 0.9)

# %% [markdown]
# The `possible_missing` field can also be useful to sort by to find objects that the model detected that may have been missed by annotators.
#
# Similarly, `possible_spurious` can be used to find instances of incorrect annotations.

# %%
session.view = dataset.match(F("possible_missing") > 0)

# %%
session.view = dataset.match(F("possible_spurious") > 0)

# %% [markdown]
# ## Tagging and resolution
#
# Any label or collection of labels can be tagged at any time in the sample grid or expanded sample view. In the expanded sample view, individual samples can be selected by clicking on them in the media player. We can, for example, tag a prediction as `missing` and any other predictions without an associated ground truth detection.
#
# Labels with specific tags can then be selected with [select_labels()](https://voxel51.com/docs/fiftyone/api/fiftyone.core.collections.html?highlight=select_labels#fiftyone.core.collections.SampleCollection.select_labels) stage and sent off to assist in improving the annotations with your annotation provided of choice. FiftyOne currently offers integrations for both [Labelbox](https://voxel51.com/docs/fiftyone/api/fiftyone.utils.labelbox.html) and [Scale](https://voxel51.com/docs/fiftyone/api/fiftyone.utils.scale.html).

# %%
# A dataset can be filtered to only contain labels with certain tags
# Helpful for isolating labels with issues and sending off to an annotation provider
missing_ground_truth = dataset.select_labels(tags="missing")

# %%
session.view = missing_ground_truth

# %% [markdown]
# **REMEMBER**: Since you are using model predictions to guide the mistakenness process, the better your model, the more accurate the mistakenness suggestions. Additionally, using logits of confidence scores will also provide better results.
